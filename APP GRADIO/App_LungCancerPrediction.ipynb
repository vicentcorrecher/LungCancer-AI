# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 24.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 6.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 20.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 19.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.1 MB/s eta 0:00:00
# ...

# %%
#  import tensorflow as tf
#  import tensorflow.keras.backend as K
#  from tensorflow.keras.applications.inception_v3 import InceptionV3
#  from tensorflow.keras.preprocessing import image
#  from tensorflow.keras.applications.inception_v3 import preprocess_input, decode_predictions
#  import numpy as np
#  import os
#  import matplotlib.pyplot as plt
#  import cv2
#  from google.colab.patches import cv2_imshow
#  from google.colab import drive
#  from keras.models import load_model
#  import gradio as gr

# %%
#  model = InceptionV3(weights='imagenet')
#  from google.colab import drive
#  drive.mount('/content/drive')
#  ORIGINAL = '/content/drive/MyDrive/Master IA^3/TFM/Sistema de detección prematura de cáncer de tórax/APP/Imagenes/Fotos299/1.png'
#  DIM = 299
#  img = image.load_img(ORIGINAL, target_size=(DIM, DIM))
#  x = image.img_to_array(img)
#  x = np.expand_dims(x, axis=0)
#  x = preprocess_input(x)
#  preds = model.predict(x)
#  with tf.GradientTape() as tape:
#    last_conv_layer = model.get_layer('conv2d_93')
#    iterate = tf.keras.models.Model([model.inputs], [model.output, last_conv_layer.output])
#    model_out, last_conv_layer = iterate(x)
#    class_out = model_out[:, np.argmax(model_out[0])]
#    grads = tape.gradient(class_out, last_conv_layer)
#    pooled_grads = K.mean(grads, axis=(0, 1, 2))

#  heatmap = tf.reduce_mean(tf.multiply(pooled_grads, last_conv_layer), axis=-1)

#  heatmap = np.maximum(heatmap, 0)
#  heatmap /= np.max(heatmap)
#  heatmap = heatmap.reshape((8, 8))
#  img = cv2.imread(ORIGINAL)
#  INTENSITY = 0.5
#  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
#  heatmap = cv2.applyColorMap(np.uint8(255*heatmap), cv2.COLORMAP_JET)
#  img = heatmap * INTENSITY + img
#  cv2_imshow(img)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 1/1 [==============================] - 5s 5s/step
# <PIL.Image.Image image mode=RGB size=299x299>

# %%
#  model = InceptionV3(weights='imagenet')
#  from google.colab import drive
#  drive.mount('/content/drive')
#  ORIGINAL = '/content/drive/MyDrive/Master IA^3/TFM/Sistema de detección prematura de cáncer de tórax/APP/Imagenes/Fotos299/1.png'
#  DIM = 299
#  img = image.load_img(ORIGINAL, target_size=(DIM, DIM))
#  x = image.img_to_array(img)
#  x = np.expand_dims(x, axis=0)
#  x = preprocess_input(x)
#  preds = model.predict(x)
#  with tf.GradientTape() as tape:
#    last_conv_layer = model.get_layer('conv2d_93')
#    iterate = tf.keras.models.Model([model.inputs], [model.output, last_conv_layer.output])
#    model_out, last_conv_layer = iterate(x)
#    class_out = model_out[:, np.argmax(model_out[0])]
#    grads = tape.gradient(class_out, last_conv_layer)
#    pooled_grads = K.mean(grads, axis=(0, 1, 2))

#  heatmap = tf.reduce_mean(tf.multiply(pooled_grads, last_conv_layer), axis=-1)

#  heatmap = np.maximum(heatmap, 0)
#  heatmap /= np.max(heatmap)
#  heatmap = heatmap.reshape((8, 8))
#  img = cv2.imread(ORIGINAL)
#  INTENSITY = 0.5
#  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
#  heatmap = cv2.applyColorMap(np.uint8(255*heatmap), cv2.COLORMAP_JET)
#  img = heatmap * INTENSITY + img
#  cv2_imshow(img)

# %%
# import tensorflow as tf
# import tensorflow.keras.backend as K
# from tensorflow.keras.applications.inception_v3 import InceptionV3
# from tensorflow.keras.preprocessing import image
# from tensorflow.keras.applications.inception_v3 import preprocess_input
# import numpy as np
# import cv2
# from google.colab.patches import cv2_imshow
# import gradio as gr

# # Carga el modelo preentrenado InceptionV3
# model = InceptionV3(weights='imagenet')

# def predict_with_gradcam(img):
#     """
#     Realiza el análisis Grad-CAM en una imagen y devuelve la imagen procesada.

#     Args:
#         img: Matriz NumPy que representa la imagen.

#     Returns:
#         Una matriz NumPy que representa la imagen procesada con la superposición de Grad-CAM.
#     """
#     x = image.img_to_array(img)
#     x = np.expand_dims(x, axis=0)
#     x = preprocess_input(x)
#     preds = model.predict(x)
#     with tf.GradientTape() as tape:
#       last_conv_layer = model.get_layer('conv2d_93')
#       iterate = tf.keras.models.Model([model.inputs], [model.output, last_conv_layer.output])
#       model_out, last_conv_layer = iterate(x)
#       class_out = model_out[:, np.argmax(model_out[0])]
#       grads = tape.gradient(class_out, last_conv_layer)
#       pooled_grads = K.mean(grads, axis=(0, 1, 2))

#     heatmap = tf.reduce_mean(tf.multiply(pooled_grads, last_conv_layer), axis=-1)

#     heatmap = np.maximum(heatmap, 0)
#     heatmap /= np.max(heatmap)
#     heatmap = heatmap.reshape((8, 8))


#     INTENSITY = 0.5
#     heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
#     heatmap = cv2.applyColorMap(np.uint8(255*heatmap), cv2.COLORMAP_JET)
#     img_hm = heatmap * INTENSITY + img
#     cv2_imshow(img_hm)

#     return img_hm

# # Interfaz Gradio
# interface = gr.Interface(
#     fn=predict_with_gradcam,
#     inputs="image",
#     outputs="image",
#     title="Grad-CAM para Clasificación de Imágenes",
#     description="Carga una imagen y visualiza las regiones influyentes con Grad-CAM."
# )

# interface.launch(debug=True)

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input
import numpy as np
import cv2
import gradio as gr

model = InceptionV3(weights='imagenet')

def predict_with_gradcam(img):

    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = model.predict(x)
    with tf.GradientTape() as tape:
        last_conv_layer = model.get_layer('conv2d_93')
        iterate = tf.keras.models.Model([model.inputs], [model.output, last_conv_layer.output])
        model_out, last_conv_layer = iterate(x)
        class_out = model_out[:, np.argmax(model_out[0])]
        grads = tape.gradient(class_out, last_conv_layer)
        pooled_grads = K.mean(grads, axis=(0, 1, 2))

    heatmap = tf.reduce_mean(tf.multiply(pooled_grads, last_conv_layer), axis=-1)

    heatmap = np.maximum(heatmap, 0)
    heatmap /= np.max(heatmap)
    heatmap = heatmap.reshape((8, 8))
    INTENSITY = 0.5
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    heatmap = cv2.applyColorMap(np.uint8(255*heatmap), cv2.COLORMAP_JET)
    img_hm = heatmap * INTENSITY + img
    img_hm = img_hm - np.min(img_hm)
    img_hm = img_hm / np.max(img_hm)


    return img_hm


# Interfaz Gradio
interface = gr.Interface(
    fn=predict_with_gradcam,
    inputs="image",
    outputs="image",
    title="Grad-CAM para predicción de malignidad de cáncer de pulmón",
    description="Carga una imagen y visualiza las regiones influyentes de la tomografía computarizada de baja dosis.",
)

interface.launch(debug=True)
# Out:
# ...
# 96112376/96112376 [==============================] - 1s 0us/step
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://6b81f37536c1575b53.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://6b81f37536c1575b53.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ...
# 1/1 [==============================] - 0s 453ms/step
